# %% [markdown]
# # Deep Learning
# ## HW1 - Problem 1 - Recommender System (100 + 20 pts)

# %% [markdown]
# ### Please fill this part
#
#
# 1.   Full Name: Ali Nourian
# 2.   Student Number: 98102527
#
#
# *You are just allowded to change those parts that start with "TO DO". Please do not change other parts.*
#
# *It is highly recommended to read each codeline carefully and try to understand what it exactly does. Best of luck and have fun!*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import string
import re
import matplotlib.pyplot as plt
import math
from matplotlib import rc
from google.colab import drive
from sklearn.model_selection import train_test_split
import matplotlib.ticker as ticker
from math import sqrt


from sklearn.metrics import mean_squared_error

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.3)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)

# %%
# Change the address as you wish
plays = pd.read_csv('user_artists.dat', sep='\t')
artists = pd.read_csv('artists.dat', sep='\t', usecols=['id','name'])

# %% [markdown]
# # Preprocessing (20 pts)

# %%
###############################################################################
## TODO: merge two DataSets in a way that below DataFrame is created         ##
###############################################################################

# ap = pd.concat([artists, plays],axis=1)

ap = pd.merge(
  artists, plays,
  left_on="id",
  right_on="artistID"
)

# %%
ap
# Out:
#           id              name  userID  artistID  weight
# 0          1      MALICE MIZER      34         1     212
# 1          1      MALICE MIZER     274         1     483
# 2          1      MALICE MIZER     785         1      76
# 3          2   Diary of Dreams     135         2    1021
# 4          2   Diary of Dreams     257         2     152
# ...      ...               ...     ...       ...     ...
# 92829  18741    Diamanda Galás     454     18741     301
# 92830  18742            Aya RL     454     18742     294
# 92831  18743       Coptic Rain     454     18743     287
# 92832  18744      Oz Alchemist     454     18744     286
# 92833  18745  Grzegorz Tomczak     585     18745     426
#
# [92834 rows x 5 columns]

# %%
###############################################################################
## TODO: rename the weight columns to PlayCount         ##
###############################################################################
ap = ap.rename(columns={"weight": "playCount"})

# %%
###############################################################################
## TODO: Delete the "id" columns and reset_indexes of ap                     ##
###############################################################################

ap = ap.drop('id',axis=1)
ap
# Out:
#                    name  userID  artistID  playCount
# 0          MALICE MIZER      34         1        212
# 1          MALICE MIZER     274         1        483
# 2          MALICE MIZER     785         1         76
# 3       Diary of Dreams     135         2       1021
# 4       Diary of Dreams     257         2        152
# ...                 ...     ...       ...        ...
# 92829    Diamanda Galás     454     18741        301
# 92830            Aya RL     454     18742        294
# 92831       Coptic Rain     454     18743        287
# 92832      Oz Alchemist     454     18744        286
# 92833  Grzegorz Tomczak     585     18745        426
#
# [92834 rows x 4 columns]

# %%
###############################################################################
## TODO: Create  a Dataframe like below where "totalUniqueUsers" is the number of
## userID's assigned to each name in "ap" dataframe.
## "totalArtistPlays" is sum of all playcounts assigned to an artist  
## and sort the Frame in descending order of "totalArtistPlays" (highest "totalArtistPlays" at top of table) 
## and "avgUserPlays" is divison of "totalArtistPlays" by "totalUniqueUsers"  
###############################################################################


artist_rank = ap.groupby(['name']).agg({'userID' : 'count', 'playCount' : 'sum'}) \
  .rename(columns={'userID' : 'totalUniqueUsers', 'playCount' : 'totalArtistPlays'}) \
  .sort_values(['totalArtistPlays'], ascending=False)

artist_rank['avgUserPlays'] = artist_rank['totalArtistPlays'] / artist_rank['totalUniqueUsers']

# %%
artist_rank
# Out:
#                     totalUniqueUsers  totalArtistPlays  avgUserPlays
# name
# Britney Spears                   522           2393140   4584.559387
# Depeche Mode                     282           1301308   4614.567376
# Lady Gaga                        611           1291387   2113.563011
# Christina Aguilera               407           1058405   2600.503686
# Paramore                         399            963449   2414.659148
# ...                              ...               ...           ...
# Morris                             1                 1      1.000000
# Eddie Kendricks                    1                 1      1.000000
# Excess Pressure                    1                 1      1.000000
# My Mine                            1                 1      1.000000
# A.M. Architect                     1                 1      1.000000
#
# [17632 rows x 3 columns]

# %%
###############################################################################
## TODO: Create  a Dataframe like below where for each name in ap dataframe,
# corresponding row in artist rank is attached to it  
###############################################################################


ap = ap.join(artist_rank, on='name').sort_values(['playCount'], ascending=False)

# %%
ap.head(20)
# Out:
#                      name  userID  artistID  playCount  totalUniqueUsers  \
# 2800         Depeche Mode    1642        72     352698               282
# 35843              Thalía    2071       792     324663                26
# 27302                  U2    1094       511     320725               185
# 8152                 Blur    1905       203     257978               114
# 26670            Paramore    1664       498     227829               399
# 21191         Evanescence    1146       378     203165               226
# 14165  Christina Aguilera     514       292     176133               407
# 33309             Shakira    1983       701     172496               319
# 33127             Shakira     757       701     169596               319
# 31835           Glee Cast    1086       679     165902               249
# 26983           In Flames     903       503     146411                67
# 32498        All Time Low     946       687     144559                77
# 13324      Britney Spears     542       289     131733               522
# 21165         Evanescence     938       378     129595               226
# 13680      Britney Spears    2031       289     128654               522
# 25865  30 Seconds to Mars    1368       486     125471               216
# 5575           Pink Floyd     292       163     123065               258
# 3640            Lady Gaga    1135        89     114672               611
# 6792                 a-ha     442       187     112009                97
# 7737     System of a Down     459       198     110185               181
#
#        totalArtistPlays  avgUserPlays
# 2800            1301308   4614.567376
# 35843            350035  13462.884615
# 27302            493024   2664.994595
# 8152             318221   2791.412281
# 26670            963449   2414.659148
# 21191            513476   2272.017699
# 14165           1058405   2600.503686
# 33309            688529   2158.398119
# 33127            688529   2158.398119
# 31835            506453   2033.947791
# 26983            237148   3539.522388
# 32498            215777   2802.298701
# 13324           2393140   4584.559387
# 21165            513476   2272.017699
# 13680           2393140   4584.559387
# 25865            485532   2247.833333
# 5575             466104   1806.604651
# 3640            1291387   2113.563011
# 6792             205195   2115.412371
# 7737             277397   1532.580110

# %% [markdown]
# # Exploration

# %%
def bar_chart_int(x,y,x_label,y_label,title,caption,total_val):
    fig, ax = plt.subplots();
    fig.set_size_inches(16, 5);
    ax = sns.barplot(x[:20], y[:20], palette='Blues_r');
    ax.set_xlabel(x_label);
    ax.set_ylabel(y_label);
    ax.set_title(title);
    ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: '{:,}'.format(int(x))));

    # our bar label placement
    for p in ax.patches:
        height = p.get_height()
        pct = 100*(height/total_val)
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.1f}%'.format(pct),
                ha="center",verticalalignment='bottom',color='black', fontsize=12);

    # our caption statement
    ax.text(19, max(y[:20])*0.95, caption,horizontalalignment='right');

    plt.xticks(rotation=90);
    plt.show();

# %%
c1 = artist_rank
x = c1.index
y = c1.totalArtistPlays
x_label = 'Artist Name'
y_label = 'Total Artist Plays'
title = 'Total Plays by Artist'
caption = 'Percentage of total plays'
total_val = c1.totalArtistPlays.sum()

bar_chart_int(x,y,x_label,y_label,title,caption,total_val);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
c2 = artist_rank.sort_values(['totalUniqueUsers'],ascending=False)
x = c2.index
y = c2.totalUniqueUsers
x_label = 'Artist Name'
y_label = 'Unique Users Played'
title = 'Unique Users per Artist'
caption = 'Percentage of total unique users'
total_val = ap.userID.nunique()

bar_chart_int(x,y,x_label,y_label,title,caption,total_val)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
top_artists = artist_rank.sort_values(['totalArtistPlays'],ascending=False).index[:12]

x = artist_rank.totalUniqueUsers
y = artist_rank.totalArtistPlays
labels = artist_rank.index

fig, ax = plt.subplots(figsize=(15,10))
sns.regplot(x,y)
ax.set_title('Artist Popularity: Play Count vs Unique Users')
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '{:,.0f}'.format(y)))
ax.set_xlabel('Total Unique Users')
ax.set_ylabel('Total Artist Plays')

for i, t in enumerate(labels):
    if t in top_artists:
        ax.annotate(t,(x[i],y[i]))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Preprocessing (30 pts)

# %%
pc = ap.playCount 
play_count_scaled = (pc - pc.min()) / (pc.max() - pc.min())
ap = ap.assign(playCountScaled=play_count_scaled)

# %%
###############################################################################
## TODO: Create  a Dataframe with userID as its rows, artistID as its columns and
## "play_count_scaled" as the value of each cell, in this manner you're creating
## a table which demonstrates what rating each user has for a set of items(artists)
## Your created table should be like below example
###############################################################################

ratings_df = ap.pivot(
    index='userID', 
    columns='artistID', 
    values='playCountScaled'
)

# %%
ratings_df
# Out:
# artistID  1      2         3      4      5         6      7      8      9      \
# userID
# 2           NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 3           NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 4           NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 5           NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 6           NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# ...         ...    ...       ...    ...    ...       ...    ...    ...    ...
# 2095        NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 2096        NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 2097        NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 2099        NaN    NaN       NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 2100        NaN    NaN  0.001154    NaN    NaN  0.001143    NaN    NaN    NaN
#
# artistID  10     ...  18736  18737  18738  18739  18740  18741  18742  18743  \
# userID           ...
# 2           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2095        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2096        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2097        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2099        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2100        NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# artistID  18744  18745
# userID
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
# 5           NaN    NaN
# 6           NaN    NaN
# ...         ...    ...
# 2095        NaN    NaN
# 2096        NaN    NaN
# 2097        NaN    NaN
# 2099        NaN    NaN
# 2100        NaN    NaN
#
# [1892 rows x 17632 columns]

# %%
###############################################################################
# TODO: Fill each NaN value with 0 and return a numpy array corresponding modified DataFrame
###############################################################################


ratings = ratings_df.fillna(0).values

# %%
###############################################################################
# TODO : Calculate how sparse your data is (in percent) and print it, meaning 
# what fraction of the above table is filled with observed values.
###############################################################################

## Your Code

sparsity = len(ratings.nonzero()[0])
sparsity = sparsity / (ratings.shape[0] * ratings.shape[1]) * 100
print('{:.2f}%'.format(sparsity))

## END
# Out:
# 0.28%

# %% [markdown]
# # Fitting(Training) Model (50pts)

# %%
MIN_USER_RATINGS = 35
DELETE_RATING_COUNT = 15

###############################################################################
# TODO : Complete the below function in way that, getting ratings array, creates
# two same size arrays as train and validation, and for the users in ratings array
# that have at least "MIN_USER_RATINGS" observed ratings, choose "DELETE_RATING_COUNT"
# of these ratings, make them zero in train table and put them in validation table
# return train and validation tables
###############################################################################


def train_test_split(ratings):
    
    train = ratings.copy()
    validation = np.zeros(ratings.shape)
    
    for user in np.arange(ratings.shape[0]):
        if len(ratings[user,:].nonzero()[0]) >= MIN_USER_RATINGS:
            val_ratings = np.random.choice(ratings[user, :].nonzero()[0], size=DELETE_RATING_COUNT, replace=False)
            train[user, val_ratings] = 0
            validation[user, val_ratings] = ratings[user, val_ratings]

    return train, validation

# %%
train, val = train_test_split(ratings)

# %%
###############################################################################
# TODO : Complete below function in a way to return sqrt value of "mean_squared_error"
# between non-zero(observed) values of ground_truth and prediction. Note that you sould
# care about observed values of ground_truth table not prediction!
###############################################################################


def rmse(prediction, ground_truth):
    prediction = prediction[ground_truth.nonzero()].flatten() 
    ground_truth = ground_truth[ground_truth.nonzero()].flatten()
    return sqrt(mean_squared_error(prediction, ground_truth))

# %%
class Recommender:
  
  def __init__(self, n_epochs=200, n_latent_features=3, lmbda=0.1, learning_rate=0.001):
    self.n_epochs = n_epochs
    self.n_latent_features = n_latent_features
    self.lmbda = lmbda
    self.learning_rate = learning_rate
  
  def predictions(self, P, Q):
    return np.dot(P.T, Q)
  
  def fit(self, X_train, X_val):
    m, n = X_train.shape

    self.P = 3 * np.random.rand(self.n_latent_features, m)
    self.Q = 3 * np.random.rand(self.n_latent_features, n)
    
    self.train_error = []
    self.val_error = []

    users, items = X_train.nonzero()
    
    for epoch in range(self.n_epochs):
        for u, i in zip(users, items):
            error = X_train[u, i] - self.predictions(self.P[:,u], self.Q[:,i])
            self.P[:, u] += self.learning_rate * (error * self.Q[:, i] - self.lmbda * self.P[:, u])
            self.Q[:, i] += self.learning_rate * (error * self.P[:, u] - self.lmbda * self.Q[:, i])

        train_rmse = rmse(self.predictions(self.P, self.Q), X_train)
        val_rmse = rmse(self.predictions(self.P, self.Q), X_val)
        self.train_error.append(train_rmse)
        self.val_error.append(val_rmse)
        print('Epoch[{}]: train error is {:.2f}, validation error is {:.2f}'.format(epoch, train_rmse, val_rmse))
    
    return self

  def predict(self, X_train, user_index):
    y_hat = self.predictions(self.P, self.Q)
    predictions_index = np.where(X_train[user_index, :] == 0)[0]
    return y_hat[user_index, predictions_index].flatten()

# %%
#creating recommender object
recommender = Recommender().fit(train, val)
# Out:
# Epoch[0]: train error is 4.92, validation error is 4.99
# Epoch[1]: train error is 3.84, validation error is 3.95
# Epoch[2]: train error is 3.16, validation error is 3.30
# Epoch[3]: train error is 2.69, validation error is 2.83
# Epoch[4]: train error is 2.32, validation error is 2.48
# Epoch[5]: train error is 2.04, validation error is 2.21
# Epoch[6]: train error is 1.82, validation error is 1.98
# Epoch[7]: train error is 1.64, validation error is 1.80
# Epoch[8]: train error is 1.48, validation error is 1.65
# Epoch[9]: train error is 1.36, validation error is 1.53
# Epoch[10]: train error is 1.25, validation error is 1.42
# Epoch[11]: train error is 1.16, validation error is 1.33
# Epoch[12]: train error is 1.08, validation error is 1.25
# Epoch[13]: train error is 1.01, validation error is 1.18
# Epoch[14]: train error is 0.95, validation error is 1.12
# Epoch[15]: train error is 0.90, validation error is 1.06
# Epoch[16]: train error is 0.85, validation error is 1.01
# Epoch[17]: train error is 0.81, validation error is 0.97
# Epoch[18]: train error is 0.77, validation error is 0.93
# Epoch[19]: train error is 0.74, validation error is 0.89
# Epoch[20]: train error is 0.71, validation error is 0.86
# Epoch[21]: train error is 0.68, validation error is 0.83
# Epoch[22]: train error is 0.65, validation error is 0.80
# Epoch[23]: train error is 0.63, validation error is 0.78
# Epoch[24]: train error is 0.61, validation error is 0.76
# Epoch[25]: train error is 0.59, validation error is 0.73
# Epoch[26]: train error is 0.57, validation error is 0.71
# Epoch[27]: train error is 0.55, validation error is 0.69
# Epoch[28]: train error is 0.53, validation error is 0.68
# Epoch[29]: train error is 0.52, validation error is 0.66
# Epoch[30]: train error is 0.50, validation error is 0.64
# Epoch[31]: train error is 0.49, validation error is 0.63
# Epoch[32]: train error is 0.48, validation error is 0.61
# Epoch[33]: train error is 0.46, validation error is 0.60
# Epoch[34]: train error is 0.45, validation error is 0.59
# Epoch[35]: train error is 0.44, validation error is 0.57
# Epoch[36]: train error is 0.43, validation error is 0.56
# Epoch[37]: train error is 0.42, validation error is 0.55
# Epoch[38]: train error is 0.41, validation error is 0.54
# Epoch[39]: train error is 0.40, validation error is 0.53
# Epoch[40]: train error is 0.39, validation error is 0.52
# Epoch[41]: train error is 0.38, validation error is 0.51
# Epoch[42]: train error is 0.38, validation error is 0.50
# Epoch[43]: train error is 0.37, validation error is 0.49
# Epoch[44]: train error is 0.36, validation error is 0.49
# Epoch[45]: train error is 0.35, validation error is 0.48
# Epoch[46]: train error is 0.35, validation error is 0.47
# Epoch[47]: train error is 0.34, validation error is 0.46
# Epoch[48]: train error is 0.33, validation error is 0.45
# Epoch[49]: train error is 0.33, validation error is 0.45
# Epoch[50]: train error is 0.32, validation error is 0.44
# Epoch[51]: train error is 0.31, validation error is 0.43
# Epoch[52]: train error is 0.31, validation error is 0.43
# Epoch[53]: train error is 0.30, validation error is 0.42
# Epoch[54]: train error is 0.30, validation error is 0.41
# Epoch[55]: train error is 0.29, validation error is 0.41
# Epoch[56]: train error is 0.29, validation error is 0.40
# Epoch[57]: train error is 0.28, validation error is 0.40
# Epoch[58]: train error is 0.28, validation error is 0.39
# Epoch[59]: train error is 0.27, validation error is 0.39
# Epoch[60]: train error is 0.27, validation error is 0.38
# Epoch[61]: train error is 0.26, validation error is 0.38
# Epoch[62]: train error is 0.26, validation error is 0.37
# Epoch[63]: train error is 0.26, validation error is 0.37
# Epoch[64]: train error is 0.25, validation error is 0.36
# Epoch[65]: train error is 0.25, validation error is 0.36
# Epoch[66]: train error is 0.24, validation error is 0.35
# Epoch[67]: train error is 0.24, validation error is 0.35
# Epoch[68]: train error is 0.24, validation error is 0.34
# Epoch[69]: train error is 0.23, validation error is 0.34
# Epoch[70]: train error is 0.23, validation error is 0.33
# Epoch[71]: train error is 0.23, validation error is 0.33
# Epoch[72]: train error is 0.22, validation error is 0.33
# Epoch[73]: train error is 0.22, validation error is 0.32
# Epoch[74]: train error is 0.22, validation error is 0.32
# Epoch[75]: train error is 0.21, validation error is 0.32
# Epoch[76]: train error is 0.21, validation error is 0.31
# Epoch[77]: train error is 0.21, validation error is 0.31
# Epoch[78]: train error is 0.20, validation error is 0.30
# Epoch[79]: train error is 0.20, validation error is 0.30
# Epoch[80]: train error is 0.20, validation error is 0.30
# Epoch[81]: train error is 0.20, validation error is 0.29
# Epoch[82]: train error is 0.19, validation error is 0.29
# Epoch[83]: train error is 0.19, validation error is 0.29
# Epoch[84]: train error is 0.19, validation error is 0.29
# Epoch[85]: train error is 0.19, validation error is 0.28
# Epoch[86]: train error is 0.18, validation error is 0.28
# Epoch[87]: train error is 0.18, validation error is 0.28
# Epoch[88]: train error is 0.18, validation error is 0.27
# Epoch[89]: train error is 0.18, validation error is 0.27
# Epoch[90]: train error is 0.17, validation error is 0.27
# Epoch[91]: train error is 0.17, validation error is 0.27
# Epoch[92]: train error is 0.17, validation error is 0.26
# Epoch[93]: train error is 0.17, validation error is 0.26
# Epoch[94]: train error is 0.16, validation error is 0.26
# Epoch[95]: train error is 0.16, validation error is 0.26
# Epoch[96]: train error is 0.16, validation error is 0.25
# Epoch[97]: train error is 0.16, validation error is 0.25
# Epoch[98]: train error is 0.16, validation error is 0.25
# Epoch[99]: train error is 0.15, validation error is 0.25
# Epoch[100]: train error is 0.15, validation error is 0.24
# Epoch[101]: train error is 0.15, validation error is 0.24
# Epoch[102]: train error is 0.15, validation error is 0.24
# Epoch[103]: train error is 0.15, validation error is 0.24
# Epoch[104]: train error is 0.15, validation error is 0.23
# Epoch[105]: train error is 0.14, validation error is 0.23
# Epoch[106]: train error is 0.14, validation error is 0.23
# Epoch[107]: train error is 0.14, validation error is 0.23
# Epoch[108]: train error is 0.14, validation error is 0.23
# Epoch[109]: train error is 0.14, validation error is 0.22
# Epoch[110]: train error is 0.14, validation error is 0.22
# Epoch[111]: train error is 0.13, validation error is 0.22
# Epoch[112]: train error is 0.13, validation error is 0.22
# Epoch[113]: train error is 0.13, validation error is 0.22
# Epoch[114]: train error is 0.13, validation error is 0.21
# Epoch[115]: train error is 0.13, validation error is 0.21
# Epoch[116]: train error is 0.13, validation error is 0.21
# Epoch[117]: train error is 0.13, validation error is 0.21
# Epoch[118]: train error is 0.12, validation error is 0.21
# Epoch[119]: train error is 0.12, validation error is 0.20
# Epoch[120]: train error is 0.12, validation error is 0.20
# Epoch[121]: train error is 0.12, validation error is 0.20
# Epoch[122]: train error is 0.12, validation error is 0.20
# Epoch[123]: train error is 0.12, validation error is 0.20
# Epoch[124]: train error is 0.12, validation error is 0.20
# Epoch[125]: train error is 0.11, validation error is 0.19
# Epoch[126]: train error is 0.11, validation error is 0.19
# Epoch[127]: train error is 0.11, validation error is 0.19
# Epoch[128]: train error is 0.11, validation error is 0.19
# Epoch[129]: train error is 0.11, validation error is 0.19
# Epoch[130]: train error is 0.11, validation error is 0.19
# Epoch[131]: train error is 0.11, validation error is 0.19
# Epoch[132]: train error is 0.11, validation error is 0.18
# Epoch[133]: train error is 0.11, validation error is 0.18
# Epoch[134]: train error is 0.10, validation error is 0.18
# Epoch[135]: train error is 0.10, validation error is 0.18
# Epoch[136]: train error is 0.10, validation error is 0.18
# Epoch[137]: train error is 0.10, validation error is 0.18
# Epoch[138]: train error is 0.10, validation error is 0.18
# Epoch[139]: train error is 0.10, validation error is 0.17
# Epoch[140]: train error is 0.10, validation error is 0.17
# Epoch[141]: train error is 0.10, validation error is 0.17
# Epoch[142]: train error is 0.10, validation error is 0.17
# Epoch[143]: train error is 0.10, validation error is 0.17
# Epoch[144]: train error is 0.09, validation error is 0.17
# Epoch[145]: train error is 0.09, validation error is 0.17
# Epoch[146]: train error is 0.09, validation error is 0.17
# Epoch[147]: train error is 0.09, validation error is 0.16
# Epoch[148]: train error is 0.09, validation error is 0.16
# Epoch[149]: train error is 0.09, validation error is 0.16
# Epoch[150]: train error is 0.09, validation error is 0.16
# Epoch[151]: train error is 0.09, validation error is 0.16
# Epoch[152]: train error is 0.09, validation error is 0.16
# Epoch[153]: train error is 0.09, validation error is 0.16
# Epoch[154]: train error is 0.09, validation error is 0.16
# Epoch[155]: train error is 0.09, validation error is 0.15
# Epoch[156]: train error is 0.08, validation error is 0.15
# Epoch[157]: train error is 0.08, validation error is 0.15
# Epoch[158]: train error is 0.08, validation error is 0.15
# Epoch[159]: train error is 0.08, validation error is 0.15
# Epoch[160]: train error is 0.08, validation error is 0.15
# Epoch[161]: train error is 0.08, validation error is 0.15
# Epoch[162]: train error is 0.08, validation error is 0.15
# Epoch[163]: train error is 0.08, validation error is 0.15
# Epoch[164]: train error is 0.08, validation error is 0.15
# Epoch[165]: train error is 0.08, validation error is 0.14
# Epoch[166]: train error is 0.08, validation error is 0.14
# Epoch[167]: train error is 0.08, validation error is 0.14
# Epoch[168]: train error is 0.08, validation error is 0.14
# Epoch[169]: train error is 0.07, validation error is 0.14
# Epoch[170]: train error is 0.07, validation error is 0.14
# Epoch[171]: train error is 0.07, validation error is 0.14
# Epoch[172]: train error is 0.07, validation error is 0.14
# Epoch[173]: train error is 0.07, validation error is 0.14
# Epoch[174]: train error is 0.07, validation error is 0.14
# Epoch[175]: train error is 0.07, validation error is 0.14
# Epoch[176]: train error is 0.07, validation error is 0.13
# Epoch[177]: train error is 0.07, validation error is 0.13
# Epoch[178]: train error is 0.07, validation error is 0.13
# Epoch[179]: train error is 0.07, validation error is 0.13
# Epoch[180]: train error is 0.07, validation error is 0.13
# Epoch[181]: train error is 0.07, validation error is 0.13
# Epoch[182]: train error is 0.07, validation error is 0.13
# Epoch[183]: train error is 0.07, validation error is 0.13
# Epoch[184]: train error is 0.07, validation error is 0.13
# Epoch[185]: train error is 0.07, validation error is 0.13
# Epoch[186]: train error is 0.06, validation error is 0.13
# Epoch[187]: train error is 0.06, validation error is 0.12
# Epoch[188]: train error is 0.06, validation error is 0.12
# Epoch[189]: train error is 0.06, validation error is 0.12
# Epoch[190]: train error is 0.06, validation error is 0.12
# Epoch[191]: train error is 0.06, validation error is 0.12
# Epoch[192]: train error is 0.06, validation error is 0.12
# Epoch[193]: train error is 0.06, validation error is 0.12
# Epoch[194]: train error is 0.06, validation error is 0.12
# Epoch[195]: train error is 0.06, validation error is 0.12
# Epoch[196]: train error is 0.06, validation error is 0.12
# Epoch[197]: train error is 0.06, validation error is 0.12
# Epoch[198]: train error is 0.06, validation error is 0.12
# Epoch[199]: train error is 0.06, validation error is 0.12

# %%
###############################################################################
# TODO : Plot the loss of train and loss
###############################################################################

plt.plot(recommender.train_error);
plt.plot(recommender.val_error);
plt.xlabel('Epochs')
plt.ylabel('RMS Error')
plt.legend(['Train Error', 'Validation Error']);

# %% [markdown]
# # Bonus
# **Can you improve the accuracy of model? If so, Do it and explain why it imporved! (Note that improvement must be noticable) (+10 pts)**

# %%
class NewRecommender:
  
  def __init__(self, n_epochs=150, n_latent_features=3, lmbda=0.1, learning_rate=0.01):
    self.n_epochs = n_epochs
    self.n_latent_features = n_latent_features
    self.lmbda = lmbda
    self.learning_rate = learning_rate
  
  def predictions(self, P, Q):
    return np.dot(P.T, Q)
  
  def fit(self, X_train, X_val):
    m, n = X_train.shape

    self.P = 3 * np.random.rand(self.n_latent_features, m)
    self.Q = 3 * np.random.rand(self.n_latent_features, n)
    
    self.train_error = []
    self.val_error = []

    users, items = X_train.nonzero()
    
    for epoch in range(self.n_epochs):
        for u, i in zip(users, items):
            error = X_train[u, i] - self.predictions(self.P[:,u], self.Q[:,i])
            self.P[:, u] += self.learning_rate / (1 + epoch/25) * (error * self.Q[:, i] - self.lmbda * self.P[:, u])
            self.Q[:, i] += self.learning_rate / (1 + epoch/25) * (error * self.P[:, u] - self.lmbda * self.Q[:, i])

        train_rmse = rmse(self.predictions(self.P, self.Q), X_train)
        val_rmse = rmse(self.predictions(self.P, self.Q), X_val)
        self.train_error.append(train_rmse)
        self.val_error.append(val_rmse)
        print('Epoch[{}]: train error is {:.2f}, validation error is {:.2f}'.format(epoch, train_rmse, val_rmse))
    
    return self

  def predict(self, X_train, user_index):
    y_hat = self.predictions(self.P, self.Q)
    predictions_index = np.where(X_train[user_index, :] == 0)[0]
    return y_hat[user_index, predictions_index].flatten()

# %%
newrecommender = NewRecommender().fit(train, val)
# Out:
# Epoch[0]: train error is 1.18, validation error is 1.33
# Epoch[1]: train error is 0.69, validation error is 0.84
# Epoch[2]: train error is 0.51, validation error is 0.64
# Epoch[3]: train error is 0.40, validation error is 0.53
# Epoch[4]: train error is 0.33, validation error is 0.45
# Epoch[5]: train error is 0.28, validation error is 0.40
# Epoch[6]: train error is 0.25, validation error is 0.36
# Epoch[7]: train error is 0.22, validation error is 0.32
# Epoch[8]: train error is 0.20, validation error is 0.30
# Epoch[9]: train error is 0.18, validation error is 0.27
# Epoch[10]: train error is 0.16, validation error is 0.25
# Epoch[11]: train error is 0.15, validation error is 0.24
# Epoch[12]: train error is 0.13, validation error is 0.22
# Epoch[13]: train error is 0.12, validation error is 0.21
# Epoch[14]: train error is 0.12, validation error is 0.20
# Epoch[15]: train error is 0.11, validation error is 0.19
# Epoch[16]: train error is 0.10, validation error is 0.18
# Epoch[17]: train error is 0.09, validation error is 0.17
# Epoch[18]: train error is 0.09, validation error is 0.16
# Epoch[19]: train error is 0.08, validation error is 0.16
# Epoch[20]: train error is 0.08, validation error is 0.15
# Epoch[21]: train error is 0.08, validation error is 0.15
# Epoch[22]: train error is 0.07, validation error is 0.14
# Epoch[23]: train error is 0.07, validation error is 0.14
# Epoch[24]: train error is 0.07, validation error is 0.13
# Epoch[25]: train error is 0.06, validation error is 0.13
# Epoch[26]: train error is 0.06, validation error is 0.12
# Epoch[27]: train error is 0.06, validation error is 0.12
# Epoch[28]: train error is 0.06, validation error is 0.12
# Epoch[29]: train error is 0.05, validation error is 0.11
# Epoch[30]: train error is 0.05, validation error is 0.11
# Epoch[31]: train error is 0.05, validation error is 0.11
# Epoch[32]: train error is 0.05, validation error is 0.10
# Epoch[33]: train error is 0.05, validation error is 0.10
# Epoch[34]: train error is 0.05, validation error is 0.10
# Epoch[35]: train error is 0.04, validation error is 0.10
# Epoch[36]: train error is 0.04, validation error is 0.09
# Epoch[37]: train error is 0.04, validation error is 0.09
# Epoch[38]: train error is 0.04, validation error is 0.09
# Epoch[39]: train error is 0.04, validation error is 0.09
# Epoch[40]: train error is 0.04, validation error is 0.09
# Epoch[41]: train error is 0.04, validation error is 0.08
# Epoch[42]: train error is 0.04, validation error is 0.08
# Epoch[43]: train error is 0.04, validation error is 0.08
# Epoch[44]: train error is 0.03, validation error is 0.08
# Epoch[45]: train error is 0.03, validation error is 0.08
# Epoch[46]: train error is 0.03, validation error is 0.08
# Epoch[47]: train error is 0.03, validation error is 0.08
# Epoch[48]: train error is 0.03, validation error is 0.07
# Epoch[49]: train error is 0.03, validation error is 0.07
# Epoch[50]: train error is 0.03, validation error is 0.07
# Epoch[51]: train error is 0.03, validation error is 0.07
# Epoch[52]: train error is 0.03, validation error is 0.07
# Epoch[53]: train error is 0.03, validation error is 0.07
# Epoch[54]: train error is 0.03, validation error is 0.07
# Epoch[55]: train error is 0.03, validation error is 0.07
# Epoch[56]: train error is 0.03, validation error is 0.07
# Epoch[57]: train error is 0.03, validation error is 0.06
# Epoch[58]: train error is 0.03, validation error is 0.06
# Epoch[59]: train error is 0.03, validation error is 0.06
# Epoch[60]: train error is 0.03, validation error is 0.06
# Epoch[61]: train error is 0.03, validation error is 0.06
# Epoch[62]: train error is 0.02, validation error is 0.06
# Epoch[63]: train error is 0.02, validation error is 0.06
# Epoch[64]: train error is 0.02, validation error is 0.06
# Epoch[65]: train error is 0.02, validation error is 0.06
# Epoch[66]: train error is 0.02, validation error is 0.06
# Epoch[67]: train error is 0.02, validation error is 0.06
# Epoch[68]: train error is 0.02, validation error is 0.06
# Epoch[69]: train error is 0.02, validation error is 0.05
# Epoch[70]: train error is 0.02, validation error is 0.05
# Epoch[71]: train error is 0.02, validation error is 0.05
# Epoch[72]: train error is 0.02, validation error is 0.05
# Epoch[73]: train error is 0.02, validation error is 0.05
# Epoch[74]: train error is 0.02, validation error is 0.05
# Epoch[75]: train error is 0.02, validation error is 0.05
# Epoch[76]: train error is 0.02, validation error is 0.05
# Epoch[77]: train error is 0.02, validation error is 0.05
# Epoch[78]: train error is 0.02, validation error is 0.05
# Epoch[79]: train error is 0.02, validation error is 0.05
# Epoch[80]: train error is 0.02, validation error is 0.05
# Epoch[81]: train error is 0.02, validation error is 0.05
# Epoch[82]: train error is 0.02, validation error is 0.05
# Epoch[83]: train error is 0.02, validation error is 0.05
# Epoch[84]: train error is 0.02, validation error is 0.05
# Epoch[85]: train error is 0.02, validation error is 0.05
# Epoch[86]: train error is 0.02, validation error is 0.05
# Epoch[87]: train error is 0.02, validation error is 0.05
# Epoch[88]: train error is 0.02, validation error is 0.04
# Epoch[89]: train error is 0.02, validation error is 0.04
# Epoch[90]: train error is 0.02, validation error is 0.04
# Epoch[91]: train error is 0.02, validation error is 0.04
# Epoch[92]: train error is 0.02, validation error is 0.04
# Epoch[93]: train error is 0.02, validation error is 0.04
# Epoch[94]: train error is 0.02, validation error is 0.04
# Epoch[95]: train error is 0.02, validation error is 0.04
# Epoch[96]: train error is 0.02, validation error is 0.04
# Epoch[97]: train error is 0.02, validation error is 0.04
# Epoch[98]: train error is 0.02, validation error is 0.04
# Epoch[99]: train error is 0.02, validation error is 0.04
# Epoch[100]: train error is 0.02, validation error is 0.04
# Epoch[101]: train error is 0.02, validation error is 0.04
# Epoch[102]: train error is 0.02, validation error is 0.04
# Epoch[103]: train error is 0.02, validation error is 0.04
# Epoch[104]: train error is 0.02, validation error is 0.04
# Epoch[105]: train error is 0.02, validation error is 0.04
# Epoch[106]: train error is 0.02, validation error is 0.04
# Epoch[107]: train error is 0.02, validation error is 0.04
# Epoch[108]: train error is 0.02, validation error is 0.04
# Epoch[109]: train error is 0.02, validation error is 0.04
# Epoch[110]: train error is 0.02, validation error is 0.04
# Epoch[111]: train error is 0.02, validation error is 0.04
# Epoch[112]: train error is 0.02, validation error is 0.04
# Epoch[113]: train error is 0.02, validation error is 0.04
# Epoch[114]: train error is 0.02, validation error is 0.04
# Epoch[115]: train error is 0.02, validation error is 0.04
# Epoch[116]: train error is 0.02, validation error is 0.04
# Epoch[117]: train error is 0.02, validation error is 0.04
# Epoch[118]: train error is 0.02, validation error is 0.03
# Epoch[119]: train error is 0.02, validation error is 0.03
# Epoch[120]: train error is 0.01, validation error is 0.03
# Epoch[121]: train error is 0.01, validation error is 0.03
# Epoch[122]: train error is 0.01, validation error is 0.03
# Epoch[123]: train error is 0.01, validation error is 0.03
# Epoch[124]: train error is 0.01, validation error is 0.03
# Epoch[125]: train error is 0.01, validation error is 0.03
# Epoch[126]: train error is 0.01, validation error is 0.03
# Epoch[127]: train error is 0.01, validation error is 0.03
# Epoch[128]: train error is 0.01, validation error is 0.03
# Epoch[129]: train error is 0.01, validation error is 0.03
# Epoch[130]: train error is 0.01, validation error is 0.03
# Epoch[131]: train error is 0.01, validation error is 0.03
# Epoch[132]: train error is 0.01, validation error is 0.03
# Epoch[133]: train error is 0.01, validation error is 0.03
# Epoch[134]: train error is 0.01, validation error is 0.03
# Epoch[135]: train error is 0.01, validation error is 0.03
# Epoch[136]: train error is 0.01, validation error is 0.03
# Epoch[137]: train error is 0.01, validation error is 0.03
# Epoch[138]: train error is 0.01, validation error is 0.03
# Epoch[139]: train error is 0.01, validation error is 0.03
# Epoch[140]: train error is 0.01, validation error is 0.03
# Epoch[141]: train error is 0.01, validation error is 0.03
# Epoch[142]: train error is 0.01, validation error is 0.03
# Epoch[143]: train error is 0.01, validation error is 0.03
# Epoch[144]: train error is 0.01, validation error is 0.03
# Epoch[145]: train error is 0.01, validation error is 0.03
# Epoch[146]: train error is 0.01, validation error is 0.03
# Epoch[147]: train error is 0.01, validation error is 0.03
# Epoch[148]: train error is 0.01, validation error is 0.03
# Epoch[149]: train error is 0.01, validation error is 0.03

# %% [markdown]
# As we can see, the training error has decreased from 0.06 to 0.01 and the validation error has decreased from 0.12 to 0.03, even in fewer epochs numbers.
#
#
# $$ \eta_i = \frac{0.01}{1 + \frac{i}{25}} $$ where $i$ is the # of epoch.

# %% [markdown]
# # Making recommendations

# %%
user_id = 1236
user_index = ratings_df.index.get_loc(user_id)
predictions_index = np.where(train[user_index, :] == 0)[0]

rating_predictions = recommender.predict(train, user_index)

# %%
def create_artist_ratings(artists_df, artists_index, ratings, n=10):
  artist_ids = ratings_df.columns[artists_index]
  artist_ratings = pd.DataFrame(data=dict(artistId=artist_ids, rating=ratings))
  top_n_artists = artist_ratings.sort_values("rating", ascending=False).head(n)
  
  artist_recommendations = artists_df[artists_df.id.isin(top_n_artists.artistId)].reset_index(drop=True)
  artist_recommendations['rating'] = pd.Series(top_n_artists.rating.values)
  return artist_recommendations.sort_values("rating", ascending=False)

# %%
existing_ratings_index = np.where(train[user_index, :] > 0)[0]
existing_ratings = train[user_index, existing_ratings_index]

create_artist_ratings(artists, existing_ratings_index, existing_ratings)
# Out:
#      id               name    rating
# 0     7     Marilyn Manson  0.196486
# 1   472       3 Doors Down  0.043204
# 2   614          Pearl Jam  0.042016
# 3   923  Children of Bodom  0.025657
# 4   978          Disturbed  0.021690
# 5  1104          Rammstein  0.021562
# 6  1118   A Perfect Circle  0.020879
# 7  2172             Gojira  0.017051
# 8  6257         Rob Zombie  0.016280
# 9  6618                D12  0.010990

# %%
# Your Systems Recommendation for specific user_id on its unobserved ratings:
create_artist_ratings(artists, predictions_index, rating_predictions)
# Out:
#       id                               name    rating
# 0   1318                   Sander van Doorn  0.559202
# 1   3167                       Jacob Miller  0.552893
# 2   7627                      Celtas Cortos  0.552142
# 3  10995                    Camisa de Vênus  0.546361
# 4  12186  Ella Fitzgerald & Louis Armstrong  0.541477
# 5  12911                         The Answer  0.537367
# 6  14245                     Anjelika Akbar  0.536756
# 7  14940                        Medications  0.536486
# 8  15792                      Lützenkirchen  0.535515
# 9  18559                        Archie Star  0.535147

# %% [markdown]
# # Bonus
# **Whatever innovation you can the on representing results of your system visually (+5 pts, note that top visualizations in sense of innovation will get the point)**

# %%
# for user id = 1236

existing_ratings_table = create_artist_ratings(artists, existing_ratings_index, existing_ratings)
prediction_ratings_table = create_artist_ratings(artists, predictions_index, rating_predictions)

# %%
existing_ratings_table.info()
prediction_ratings_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   name    10 non-null     object
#  2   rating  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   name    10 non-null     object
#  2   rating  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
xe = existing_ratings_table.name
ye = existing_ratings_table.rating

xp = prediction_ratings_table.name
yp = prediction_ratings_table.rating

x_label = 'Artist Name'
y_label = 'Rating'
title1 = 'Existing Ratings'
title2 = 'Prediction Ratings'

plt.bar(xe[0:20], ye[:20]);
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title1)
plt.xticks(rotation=90)
plt.show()

plt.bar(xp[0:20], yp[:20]);
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(title2)
plt.xticks(rotation=90)
plt.show()
